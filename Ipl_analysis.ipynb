# %% [markdown]
# # by Umamahesh Yenamala

# %%
import pandas as pd

# %%
df=pd.read_csv("deliveries.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df1=pd.read_csv("matches.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # 1. Which of the following is the right way to merge 2 datasets for getting better insights from the data1

# %%
merged_df = pd.merge(df, df1, left_on='match_id', right_on='id', how='inner')

# %%
merged_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  result  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 39 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# # 2. The column which has the most missing values according to the data is:
# *

# %%
merged_df['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                            17991
# Wankhede Stadium                                        17590
# M Chinnaswamy Stadium                                   16872
# Feroz Shah Kotla                                        15604
# Rajiv Gandhi International Stadium, Uppal               13303
# MA Chidambaram Stadium, Chepauk                         12006
# Sawai Mansingh Stadium                                  11158
# Punjab Cricket Association Stadium, Mohali               8266
# Maharashtra Cricket Association Stadium                  5055
# Subrata Roy Sahara Stadium                               4064
# Dr DY Patil Sports Academy                               3993
# Kingsmead                                                3643
# Punjab Cricket Association IS Bindra Stadium, Mohali     3315
# Sardar Patel Stadium, Motera                             2893
# SuperSport Park                                          2866
# ...

# %% [markdown]
# # 3. City which hosted most number of seasons according to the data is:

# %%
merged_df['city'].value_counts()
# Out:
# city
# Mumbai            24302
# Kolkata           17991
# Delhi             17305
# Hyderabad         15215
# Bangalore         15155
# Chennai           13895
# Jaipur            11158
# Chandigarh        10840
# Pune               9119
# Durban             3643
# Bengaluru          3248
# Visakhapatnam      3037
# Ahmedabad          2893
# Centurion          2866
# Mohali             2431
# Rajkot             2381
# Dharamsala         2159
# Indore             1965
# Johannesburg       1940
# Cuttack            1695
# Port Elizabeth     1677
# Ranchi             1671
# Abu Dhabi          1624
# Cape Town          1539
# Sharjah            1439
# Raipur             1431
# Kochi              1155
# Kanpur              921
# Nagpur              742
# Kimberley           726
# East London         715
# Bloemfontein        500
# Name: count, dtype: int64

# %% [markdown]
# # 4. Which year has the most number of matches played?

# %%
merged_df['date'] = pd.to_datetime(merged_df['date'], errors='coerce')

# %%
merged_df['date']=="NaT"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 179073    False
# 179074    False
# 179075    False
# 179076    False
# 179077    False
# Name: date, Length: 179078, dtype: bool

# %%
merged_df['date'].value_counts()
# Out:
# date
# 2009-04-23    513
# 2017-04-29    508
# 2012-05-05    506
# 2013-04-16    506
# 2014-05-19    503
#              ...
# 2012-04-05    142
# 2008-05-16    136
# 2015-04-29    128
# 2015-05-13    126
# 2015-05-15    106
# Name: count, Length: 450, dtype: int64

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 39 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
gp=merged_df.groupby('')

# %%
merged_df['year']=merged_df['date'].dt.year

# %%
merged_df['year'].value_counts()
# Out:
# year
# 2013.0    18177
# 2012.0    17767
# 2011.0    17013
# 2010.0    14498
# 2014.0    14300
# 2016.0    14096
# 2017.0    13862
# 2015.0    13652
# 2009.0    13606
# 2008.0    13489
# Name: count, dtype: int64

# %%
merged_df['date']
# Out:
# 0         2017-04-05
# 1         2017-04-05
# 2         2017-04-05
# 3         2017-04-05
# 4         2017-04-05
#              ...
# 179073      12/05/19
# 179074      12/05/19
# 179075      12/05/19
# 179076      12/05/19
# 179077      12/05/19
# Name: date, Length: 179078, dtype: object

# %%
def convert_to_datetime(date_str):
    try:
        # Try parsing with the first format
        return pd.to_datetime(date_str, format='%Y-%m-%d')
    except ValueError:
        try:
            # Try parsing with the second format
            return pd.to_datetime(date_str, format='%m/%d/%y')
        except ValueError:
            # If both formats fail, return NaT
            return pd.NaT

# Apply the custom function to each element in the date_data
merged_df['date'] = pd.Series(merged_df['date']).apply(convert_to_datetime)

# %%
merged_df['date'].dt.year.value_counts()
# Out:
# date
# 2013.0    18177
# 2012.0    17767
# 2011.0    17013
# 2010.0    14498
# 2014.0    14300
# 2016.0    14096
# 2017.0    13862
# 2015.0    13652
# 2009.0    13606
# 2008.0    13489
# 2019.0     5995
# 2018.0     5175
# Name: count, dtype: int64

# %% [markdown]
# # 5. Maximum wins by Mumbai Indians in 2011 are

# %%
merged_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3'],
#       dtype='object')

# %%
merged_df['year']=merged_df['date'].dt.year

# %%
merged_df['year'].value_counts()
# Out:
# year
# 2013.0    18177
# 2012.0    17767
# 2011.0    17013
# 2010.0    14498
# 2014.0    14300
# 2016.0    14096
# 2017.0    13862
# 2015.0    13652
# 2009.0    13606
# 2008.0    13489
# 2019.0     5995
# 2018.0     5175
# Name: count, dtype: int64

# %%
merged_df[(merged_df['winner']=="Mumbai Indians")&(merged_df['year']==2011)]
# Out:
#        match_id  inning      batting_team           bowling_team  over  ball  \
# 56181       238       1  Delhi Daredevils         Mumbai Indians     1     1
# 56182       238       1  Delhi Daredevils         Mumbai Indians     1     2
# 56183       238       1  Delhi Daredevils         Mumbai Indians     1     3
# 56184       238       1  Delhi Daredevils         Mumbai Indians     1     4
# 56185       238       1  Delhi Daredevils         Mumbai Indians     1     5
# ...         ...     ...               ...                    ...   ...   ...
# 71968       305       2    Mumbai Indians  Kolkata Knight Riders    19     4
# 71969       305       2    Mumbai Indians  Kolkata Knight Riders    19     5
# 71970       305       2    Mumbai Indians  Kolkata Knight Riders    19     6
# 71971       305       2    Mumbai Indians  Kolkata Knight Riders    20     1
# 71972       305       2    Mumbai Indians  Kolkata Knight Riders    20     2
#
# ...

# %%
merged_df[merged_df['winner']=="Mumbai Indians"]['year']==2011
# Out:
# 1424      False
# 1425      False
# 1426      False
# 1427      False
# 1428      False
#           ...
# 179073    False
# 179074    False
# 179075    False
# 179076    False
# 179077    False
# Name: year, Length: 26305, dtype: bool

# %%
merged_df['season']
# Out:
# 0         2017
# 1         2017
# 2         2017
# 3         2017
# 4         2017
#           ...
# 179073    2019
# 179074    2019
# 179075    2019
# 179076    2019
# 179077    2019
# Name: season, Length: 179078, dtype: int64

# %%
mi_2011_wins = merged_df[(merged_df['season'] == 2011) & (merged_df['winner'] == 'Mumbai Indians')]

# Find the maximum number of wins
max_wins = mi_2011_wins['winner'].count()

# %%
max_wins
# Out:
# 2416

# %%
mi_2011_wins = merged_df[(merged_df['winner'] == 'Mumbai Indians') & (merged_df['season'] == 2011)]

# Find the total number of matches won by Mumbai Indians in 2011
total_wins = mi_2011_wins['match_id'].nunique()

# %%
total_wins
# Out:
# 10

# %%
merged_df['toss_decision'].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
toss_decision_percentage = merged_df['toss_decision'].value_counts(normalize=True) * 100

# %%
toss_decision_percentage
# Out:
# toss_decision
# field    60.9913
# bat      39.0087
# Name: proportion, dtype: float64

# %%
field_wins = merged_df[merged_df['toss_decision'] == 'field']['winner'].count()

# Count the number of matches won by teams choosing to bat first
bat_wins = merged_df[merged_df['toss_decision'] == 'bat']['winner'].count()

# Compare the counts
if field_wins > bat_wins:
    print("Teams winning tosses and electing field first have won more number of matches.")
elif bat_wins > field_wins:
    print("Teams winning tosses and electing bat first have won more number of matches.")
else:
    print("Both A and B (Teams winning tosses and electing field first or bat first) have won an equal number of matches.")
# Out:
# Teams winning tosses and electing field first have won more number of matches.

# %%
batting_second_wins = merged_df[(merged_df['inning'] == 2) | (merged_df['toss_decision'] == 'field')]

# Count the number of matches won by teams batting second for each year
batting_second_wins_by_year = batting_second_wins.groupby('season')['winner'].count()

# Identify the years where teams batting second won more matches
years_with_more_batting_second_wins = batting_second_wins_by_year[batting_second_wins_by_year.idxmax()]

print("Years where teams batting second won more matches:")
print(years_with_more_batting_second_wins)
# Out:
# Years where teams batting second won more matches:
# 14025

# %%
batting_second_wins_by_year = batting_second_wins.groupby('season')['winner'].count()

# Identify the years where teams batting second won more matches
years_with_more_batting_second_wins = batting_second_wins_by_year[batting_second_wins_by_year.idxmax()]

print("Years where teams batting second won more matches:")
print(years_with_more_batting_second_wins)
# Out:
# Years where teams batting second won more matches:
# 14025

# %%
years_with_more_batting_second_wins = batting_second_wins_by_year[batting_second_wins_by_year == batting_second_wins_by_year.max()]

print("Years where teams batting second won more matches:")
print(years_with_more_batting_second_wins)
# Out:
# Years where teams batting second won more matches:
# season
# 2011    14025
# Name: winner, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
merged_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
merged_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  dl_applied  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...           0
#
# ...

# %%
top_10_batsmen = merged_df.sort_values(by='batsman_runs', ascending=False).head(10)

# %%
top_10_batsmen['batsman']
# Out:
# 168845            CA Lynn
# 170577         KA Pollard
# 157723    C de Grandhomme
# 174198           MS Dhoni
# 168302         KA Pollard
# 176579           MS Dhoni
# 172793          RG Sharma
# 157658        BB McCullum
# 168903         AD Russell
# 151652           DJ Bravo
# Name: batsman, dtype: object

# %%
merged_df[merged_df['batsman']=="DA Warner"]
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 176247     11339       1  Sunrisers Hyderabad              Kings XI Punjab
# 176250     11339       1  Sunrisers Hyderabad              Kings XI Punjab
# 176251     11339       1  Sunrisers Hyderabad              Kings XI Punjab
# 176252     11339       1  Sunrisers Hyderabad              Kings XI Punjab
# 176256     11339       1  Sunrisers Hyderabad              Kings XI Punjab
#
# ...

# %%
11. In 2019 which batsman scored highest number of runs by hitting 6's and 4's?
*
1 point
AD Russell
CH Gayle
KL Rahul
DA Warner
# Out:
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_8104/446898477.py", line 2
#     *
#      ^
# SyntaxError: invalid syntax

# %%
matches_2019 = merged_df[merged_df['year'] == 2019]

# Calculate total runs scored by hitting 6's and 4's for each batsman
matches_2019['total_runs_boundary'] = matches_2019['fours'] * 4 + matches_2019['sixes'] * 6

# Find the batsman who scored the highest number of runs by hitting 6's and 4's in 2019
top_batsman_2019 = matches_2019.groupby('batsman')['total_runs_boundary'].sum().idxmax()

print(f"In 2019, the batsman who scored the highest number of runs by hitting 6's and 4's: {top_batsman_2019}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3789         try:
# -> 3790             return self._engine.get_loc(casted_key)
#    3791         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fours'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8104/2246813180.py in <module>
#       2
# ...

# %%
merged_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
merged_df.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  dl_applied  \
# ...

# %%
matches_2019 = merged_df[merged_df['year'] == 2019]

# %%
matches_2019.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
matches_2019['fours'] = matches_2019['batsman_runs'].apply(lambda x: 1 if x == 4 else 0)
matches_2019['sixes'] = matches_2019['batsman_runs'].apply(lambda x: 1 if x == 6 else 0)
matches_2019['total_runs_boundary'] = matches_2019['fours'] * 4 + matches_2019['sixes'] * 6

# Find the batsman who scored the highest number of runs by hitting 6's and 4's in 2019
top_batsman_2019 = matches_2019.groupby('batsman')['total_runs_boundary'].sum().idxmax()

print(f"In 2019, the batsman who scored the highest number of runs by hitting 6's and 4's: {top_batsman_2019}")
# Out:
# In 2019, the batsman who scored the highest number of runs by hitting 6's and 4's: KL Rahul
# C:\Users\dell\AppData\Local\Temp/ipykernel_8104/2130332357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches_2019['fours'] = matches_2019['batsman_runs'].apply(lambda x: 1 if x == 4 else 0)
# C:\Users\dell\AppData\Local\Temp/ipykernel_8104/2130332357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
wickets_by_bowler = merged_df[merged_df['dismissal_kind'].notnull()].groupby('bowler').size()

# Find the bowler with the most number of wickets
most_wickets_bowler = wickets_by_bowler.idxmax()
most_wickets_count = wickets_by_bowler.max()

# %%
most_wickets_bowler
# Out:
# 'SL Malinga'

# %%
merged_df['total_boundaries'] = merged_df['fours'] + merged_df['sixes']

# Find the player with the highest total number of boundaries (indicative of hard-hitting ability)
highest_boundaries_player = merged_df.loc[merged_df['total_boundaries'].idxmax(), 'batsman']

print(f"The player with the highest hard-hitting ability is {highest_boundaries_player}.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3789         try:
# -> 3790             return self._engine.get_loc(casted_key)
#    3791         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fours'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8104/273056086.py in <module>
# ----> 1 merged_df['total_boundaries'] = merged_df['fours'] + merged_df['sixes']
# ...

# %%
highest_runs_player = merged_df.loc[merged_df['batsman_runs'].idxmax(), 'batsman']

# %%
highest_runs_player
# Out:
# 'DJ Bravo'

# %%
highest_runs_player = merged_df.loc[merged_df['total_runs'].idxmax(), 'batsman']

print(f"The player with the highest hard-hitting ability is {highest_runs_player}.")
# Out:
# The player with the highest hard-hitting ability is BB McCullum.

# %%
merged_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
caught_and_bowled_df = merged_df[merged_df['dismissal_kind'] == 'caught and bowled']

# Find the player dismissed the maximum number of times via caught and bowled
max_dismissals_player = caught_and_bowled_df['batsman'].value_counts().idxmax()

print(f"The player dismissed the maximum number of times via caught and bowled is {max_dismissals_player}.")
# Out:
# The player dismissed the maximum number of times via caught and bowled is SK Raina.

# %%
filtered_df = merged_df[(merged_df['batsman'] == 'V Kohli') & (merged_df['bowler'] == 'JJ Bumrah')]

# Calculate the total runs scored by V Kohli when the bowler was JJ Bumrah
total_runs_by_v_kohli = filtered_df['batsman_runs'].sum()

print(f"The total runs scored by V Kohli when the bowler was JJ Bumrah is {total_runs_by_v_kohli}.")
# Out:
# The total runs scored by V Kohli when the bowler was JJ Bumrah is 112.

# %%
filtered_df['batsman_runs'].sum()
# Out:
# 112

# %%
run_outs_df = merged_df[merged_df['dismissal_kind'] == 'run out']

# Find the top three batsmen with the most number of run outs
top_three_run_outs = run_outs_df['batsman'].value_counts().nlargest(3)

print("Top three batsmen with the most number of run outs:")
print(top_three_run_outs)
# Out:
# Top three batsmen with the most number of run outs:
# batsman
# MS Dhoni      21
# RG Sharma     17
# KD Karthik    16
# Name: count, dtype: int64

# %%
run_outs_df['batsman'].value_counts().nlargest(5)
# Out:
# batsman
# MS Dhoni      21
# RG Sharma     17
# KD Karthik    16
# G Gambhir     15
# V Kohli       15
# Name: count, dtype: int64

# %%
match_2017 = merged_df[(merged_df['team1'] == 'Sunrisers Hyderabad') & 
                       (merged_df['team2'] == 'Royal Challengers Bangalore') & 
                       (merged_df['season'] == 2017)]

# Find the player who won the "Player of the Match" award
player_of_match = match_2017['player_of_match'].iloc[0]

print(f"In the Sunrisers Hyderabad vs Royal Challengers Bangalore match in 2017, the Player of the Match was {player_of_match}.")
# Out:
# In the Sunrisers Hyderabad vs Royal Challengers Bangalore match in 2017, the Player of the Match was Yuvraj Singh.

# %%
match_2017['player_of_match'].iloc[0]
# Out:
# 'Yuvraj Singh'

# %%
most_hosted_venue = merged_df['venue'].value_counts().idxmax()

print(f"The venue that has hosted the most number of IPL matches is {most_hosted_venue}.")
# Out:
# The venue that has hosted the most number of IPL matches is Eden Gardens.

# %%
most_hosted_venue
# Out:
# 'Eden Gardens'

# %%
merged_df['total_extras'] = merged_df['wide_runs'] + merged_df['bye_runs'] + merged_df['legbye_runs'] + merged_df['noball_runs'] + merged_df['penalty_runs']

# Find the bowler with the maximum number of extras
max_extras_bowler = merged_df.groupby('bowler')['total_extras'].sum().idxmax()

print(f"The bowler with the maximum number of extras is {max_extras_bowler}.")
# Out:
# The bowler with the maximum number of extras is SL Malinga.

# %%
kohli_2016_df = merged_df[(merged_df['batsman'] == 'V Kohli') & (merged_df['season'] == 2016)]

# Calculate total runs and total balls faced by Kohli in 2016
total_runs = kohli_2016_df['batsman_runs'].sum()
total_balls_faced = kohli_2016_df['ball'].sum()

# Calculate the strike rate
strike_rate = (total_runs / total_balls_faced) * 100

print(f"The strike rate of Kohli in 2016 is {strike_rate:.2f}.")
# Out:
# The strike rate of Kohli in 2016 is 43.34.

# %%
kohli_2016_df
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 137017       580       1  Royal Challengers Bangalore  Sunrisers Hyderabad
# 137018       580       1  Royal Challengers Bangalore  Sunrisers Hyderabad
# 137019       580       1  Royal Challengers Bangalore  Sunrisers Hyderabad
# 137020       580       1  Royal Challengers Bangalore  Sunrisers Hyderabad
# 137026       580       1  Royal Challengers Bangalore  Sunrisers Hyderabad
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
merged_df['batsman']
# Out:
# 0         DA Warner
# 1         DA Warner
# 2         DA Warner
# 3         DA Warner
# 4         DA Warner
#             ...
# 179073    RA Jadeja
# 179074    SR Watson
# 179075    SR Watson
# 179076    SN Thakur
# 179077    SN Thakur
# Name: batsman, Length: 179078, dtype: object

# %%
batting_second_wins_df = merged_df[merged_df['team1'] == merged_df['winner']]

# Count the number of wins for each season
batting_second_wins_by_season = batting_second_wins_df['season'].value_counts()

# Find the years where taking batting second has won more matches
years_with_more_batting_second_wins = batting_second_wins_by_season[batting_second_wins_by_season == batting_second_wins_by_season.max()].index

print(f"Years where taking batting second has won more matches: {list(years_with_more_batting_second_wins)}")
# Out:
# Years where taking batting second has won more matches: [2013]

# %%
batting_second_wins_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
merged_df['year'].value_counts()
# Out:
# year
# 2013.0    18177
# 2012.0    17767
# 2011.0    17013
# 2010.0    14498
# 2014.0    14300
# 2016.0    14096
# 2017.0    13862
# 2015.0    13652
# 2009.0    13606
# 2008.0    13489
# 2019.0     5995
# 2018.0     5175
# Name: count, dtype: int64

# %%
matches_won_by_batting_second = merged_df[merged_df['toss_decision'] == 'field']['season'].value_counts()
matches_won_by_batting_first = merged_df[merged_df['toss_decision'] == 'bat']['season'].value_counts()

# Compare the counts for each season
years_where_batting_second_won_more = matches_won_by_batting_second[matches_won_by_batting_second > matches_won_by_batting_first].index

print(f"In the years {list(years_where_batting_second_won_more)}, taking batting second has won more matches.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8104/3739699001.py in <module>
#       3
#       4 # Compare the counts for each season
# ----> 5 years_where_batting_second_won_more = matches_won_by_batting_second[matches_won_by_batting_second > matches_won_by_batting_first].index
#       6
#       7 print(f"In the years {list(years_where_batting_second_won_more)}, taking batting second has won more matches.")
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ...

# %%
matches_won_by_batting_second
# Out:
# season
# 2019    11914
# 2018    11831
# 2016    11565
# 2011    11331
# 2017    11172
# 2014     9726
# 2012     8779
# 2015     7720
# 2008     7516
# 2013     7368
# 2009     5186
# 2010     5114
# Name: count, dtype: int64

# %%
matches_won_by_batting_second = merged_df[merged_df['toss_decision'] == 'field']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3789         try:
# -> 3790             return self._engine.get_loc(casted_key)
#    3791         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'season'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8104/875592957.py in <module>
# ----> 1 matches_won_by_batting_second = merged_df[merged_df['toss_decision'] == 'field']['winner']['season']
#
# ...

# %%
matches_won_by_batting_second
# Out:
# 0         Sunrisers Hyderabad
# 1         Sunrisers Hyderabad
# 2         Sunrisers Hyderabad
# 3         Sunrisers Hyderabad
# 4         Sunrisers Hyderabad
#                  ...
# 178825    Chennai Super Kings
# 178826    Chennai Super Kings
# 178827    Chennai Super Kings
# 178828    Chennai Super Kings
# 178829    Chennai Super Kings
# Name: winner, Length: 109222, dtype: object

# %%
merged_df['winner']
# Out:
# 0         Sunrisers Hyderabad
# 1         Sunrisers Hyderabad
# 2         Sunrisers Hyderabad
# 3         Sunrisers Hyderabad
# 4         Sunrisers Hyderabad
#                  ...
# 179073         Mumbai Indians
# 179074         Mumbai Indians
# 179075         Mumbai Indians
# 179076         Mumbai Indians
# 179077         Mumbai Indians
# Name: winner, Length: 179078, dtype: object

# %%
merged_df[(merged_df['toss_decision'] == 'field')]['season'].value_counts()
# Out:
# season
# 2019    11914
# 2018    11831
# 2016    11565
# 2011    11331
# 2017    11172
# 2014     9726
# 2012     8779
# 2015     7720
# 2008     7516
# 2013     7368
# 2009     5186
# 2010     5114
# Name: count, dtype: int64

# %%
merged_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3', 'year', 'total_extras'],
#       dtype='object')
